# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn
import re
import statsmodels.formula.api

from sklearn.linear_model import SGDClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

import gensim
from gensim.models import Word2Vec

# %%
# Configure how graphs will show up in this notebook
# %matplotlib inline
seaborn.set_context('notebook', rc={'figure.figsize': (10, 6)}, font_scale=1.5)

# %% [markdown]
# ### Define useful functions

# %%
def get_embedding_dataframe(model_asia_2500):
    '''Function to get the embedding dataframe from a word2vec model'''
    vocabulary = model_asia_2500.wv.vocab

    vectors = {}
    for word in vocabulary:
        vectors[word] = model_asia_2500[word]
        if len(vectors)%100000 == 0:
            print(len(vectors))
    print('Dataframe Done!')

    embedding_a2500 = pd.DataFrame.from_dict(vectors, orient='index')
    return embedding_a2500

def load_lexicon(filename):
    """
    Load a file from Bing Liu's sentiment lexicon
    (https://www.cs.uic.edu/~liub/FBS/sentiment-analysis.html), containing
    English words in Latin-1 encoding.
    
    One file contains a list of positive words, and the other contains
    a list of negative words. The files contain comment lines starting
    with ';' and blank lines, which should be skipped.
    """
    lexicon = []
    with open(filename, encoding='latin-1') as infile:
        for line in infile:
            line = line.rstrip()
            if line and not line.startswith(';'):
                lexicon.append(line)
    return lexicon

def check_in_vocab(pos_words, embedding_a2500):
    '''Function to keep positive or negative words that are in the vocabulary'''
    counter = 0
    checked_words = []
    for word in pos_words:
        if word not in list(embedding_a2500.index):
            print('{} not in list'.format(word))
        else:
            checked_words.append(word)
            #print('{} checked words'.format(len(checked_words)))
    return checked_words

def get_sa_accuracy(pos_words, neg_words, embedding_a2500):
    '''Function to get the accuracy of a sentiment analysis log classifier trained with the passed embedding'''
    
    # Keep positive and negative words that are in the embedding
    #print("Start with {} positive words, {} negative words".format(len(pos_words), len(neg_words)))
    pos_words = check_in_vocab(pos_words, embedding_a2500)
    neg_words = check_in_vocab(neg_words, embedding_a2500)
    print("After check: {} positive words, {} negative words".format(len(pos_words), len(neg_words)))
    
    # Get positive and negative vectors
    pos_vectors = embedding_a2500.loc[pos_words].dropna()
    neg_vectors = embedding_a2500.loc[neg_words].dropna()
    
    vectors = pd.concat([pos_vectors, neg_vectors])
    targets = np.array([1 for entry in pos_vectors.index] + [-1 for entry in neg_vectors.index])
    labels = list(pos_vectors.index) + list(neg_vectors.index)
    
    train_vectors, test_vectors, train_targets, test_targets, train_labels, test_labels = \
        train_test_split(vectors, targets, labels, test_size=0.1, random_state=0)
    
    sentiment_classifier = SGDClassifier(loss='log', random_state=0)
    sentiment_classifier.fit(train_vectors, train_targets)
    
    accuracy = accuracy_score(sentiment_classifier.predict(test_vectors), test_targets)
    return accuracy

# %%
### Get all embedding to be evaluated 

model_black_2500 = Word2Vec.load("../wikipedia_corpus/modelos_vectores/debiased_black/wiki_cds_bw_2500.txt.model")
embedding_black_2500 = get_embedding_dataframe(model_black_2500)

pos_words = load_lexicon('data/positive-words.txt')
neg_words = load_lexicon('data/negative-words.txt')

accuracy_b25 = get_sa_accuracy(pos_words, neg_words, embedding_black_2500)
print('Debiased black 2500 accuracy: {}'.format(accuracy_b25))
# Out:
# /Users/gabrielamaylagunes/Desktop/Berkeley/berkeley/lib/python3.7/site-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   import sys
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# Dataframe Done!
# a+ not in list
# accessable not in list
# accomodative not in list
# achievible not in list
# afordable not in list
# all-around not in list
# amiabily not in list
# awsome not in list
# beautifullly not in list
# believeable not in list
# benifits not in list
# best-known not in list
# best-performing not in list
# best-selling not in list
# better-known not in list
# better-than-expected not in list
# beutifully not in list
# brand-new not in list
# cashbacks not in list
# clear-cut not in list
# convienient not in list
# cost-effective not in list
# cost-saving not in list
# counter-attack not in list
# counter-attacks not in list
# cure-all not in list
# dead-cheap not in list
# dead-on not in list
# deginified not in list
# dirt-cheap not in list
# dummy-proof not in list
# easy-to-use not in list
# ecenomical not in list
# energy-efficient not in list
# energy-saving not in list
# enthusiastically not in list
# err-free not in list
# exaltedly not in list
# exaltingly not in list
# excallent not in list
# exceled not in list
# excellant not in list
# excitedness not in list
# exellent not in list
# exultingly not in list
# eye-catch not in list
# eye-catching not in list
# fancinating not in list
# fast-growing not in list
# fast-paced not in list
# fastest-growing not in list
# feature-rich not in list
# fecilitous not in list
# fine-looking not in list
# first-class not in list
# first-in-class not in list
# first-rate not in list
# futurestic not in list
# god-given not in list
# god-send not in list
# hands-down not in list
# hard-working not in list
# heroize not in list
# high-quality not in list
# high-spirited not in list
# imaculate not in list
# inpressed not in list
# invaluablely not in list
# issue-free not in list
# jaw-droping not in list
# jaw-dropping not in list
# jollify not in list
# jubiliant not in list
# kid-friendly not in list
# large-capacity not in list
# law-abiding not in list
# light-hearted not in list
# long-lasting not in list
# low-cost not in list
# low-price not in list
# low-priced not in list
# low-risk not in list
# lower-priced not in list
# marvelousness not in list
# mind-blowing not in list
# multi-purpose not in list
# non-violence not in list
# non-violent not in list
# pain-free not in list
# pamperedly not in list
# pamperedness not in list
# pre-eminent not in list
# problem-free not in list
# problem-solver not in list
# prospros not in list
# raptureous not in list
# raptureously not in list
# razor-sharp not in list
# recomend not in list
# record-setting not in list
# rejoicingly not in list
# righten not in list
# risk-free not in list
# rock-star not in list
# rock-stars not in list
# satisified not in list
# self-determination not in list
# self-respect not in list
# self-satisfaction not in list
# self-sufficiency not in list
# self-sufficient not in list
# shimmeringly not in list
# state-of-the-art not in list
# stellarly not in list
# supurb not in list
# supurbly not in list
# swankier not in list
# thumb-up not in list
# thumbs-up not in list
# time-honored not in list
# titillatingly not in list
# toll-free not in list
# top-notch not in list
# top-quality not in list
# trouble-free not in list
# ultra-crisp not in list
# user-friendly not in list
# user-replaceable not in list
# well-backlit not in list
# well-balanced not in list
# well-behaved not in list
# well-being not in list
# well-bred not in list
# well-connected not in list
# well-educated not in list
# well-established not in list
# well-informed not in list
# well-intentioned not in list
# well-known not in list
# well-made not in list
# well-managed not in list
# well-mannered not in list
# well-positioned not in list
# well-received not in list
# well-regarded not in list
# well-rounded not in list
# well-run not in list
# well-wishers not in list
# whooa not in list
# whoooa not in list
# wonderously not in list
# world-famous not in list
# worth-while not in list
# 2-faced not in list
# 2-faces not in list
# absent-minded not in list
# acerbate not in list
# acridly not in list
# acridness not in list
# admonishingly not in list
# adulterier not in list
# aggrivation not in list
# angriness not in list
# anti- not in list
# anti-american not in list
# anti-israeli not in list
# anti-occupation not in list
# anti-proliferation not in list
# anti-semites not in list
# anti-social not in list
# anti-us not in list
# anti-white not in list
# asininely not in list
# asinininity not in list
# audiciously not in list
# avariciously not in list
# back-logged not in list
# back-wood not in list
# back-woods not in list
# backaching not in list
# banalize not in list
# bid-rigging not in list
# bluring not in list
# break-up not in list
# break-ups not in list
# broken-hearted not in list
# bulkyness not in list
# bull**** not in list
# bull---- not in list
# bullshyt not in list
# bullyingly not in list
# bumpping not in list
# burdensomely not in list
# calumniously not in list
# cash-strapped not in list
# cataclysmal not in list
# catastrophically not in list
# catastrophies not in list
# concen not in list
# concens not in list
# conscons not in list
# corruptted not in list
# counter-productive not in list
# counterproductive not in list
# craftly not in list
# cuplrit not in list
# d*mn not in list
# demoralizingly not in list
# denunciate not in list
# deploringly not in list
# depravedly not in list
# desititute not in list
# destains not in list
# detestably not in list
# diappointed not in list
# die-hard not in list
# dilly-dally not in list
# disapointed not in list
# disapointing not in list
# disapointment not in list
# disasterous not in list
# discomfititure not in list
# discoutinous not in list
# disgruntle not in list
# disgustfully not in list
# dishonorablely not in list
# dismalness not in list
# disoobedient not in list
# dispiritedly not in list
# disproportionate not in list
# disrespectablity not in list
# disrespectfulness not in list
# dissapointed not in list
# dissappointed not in list
# dissappointing not in list
# distains not in list
# distraughtness not in list
# dizzing not in list
# dizzingly not in list
# douchbag not in list
# downheartedly not in list
# drop-out not in list
# drop-outs not in list
# election-rigger not in list
# exagerate not in list
# exagerated not in list
# exagerates not in list
# exhorbitant not in list
# exorbitantance not in list
# f**k not in list
# far-fetched not in list
# farcical-yet-provocative not in list
# fastuous not in list
# fat-cat not in list
# fat-cats not in list
# fawningly not in list
# feeblely not in list
# flakieness not in list
# flat-out not in list
# flicering not in list
# fractiously not in list
# franticly not in list
# full-blown not in list
# fustigate not in list
# gainsayer not in list
# get-rich not in list
# gimmicking not in list
# god-awful not in list
# grumpish not in list
# hairloss not in list
# hard-hit not in list
# hard-line not in list
# hard-liner not in list
# hasseling not in list
# head-aches not in list
# heavy-handed not in list
# hell-bent not in list
# hestitant not in list
# high-priced not in list
# hiliarious not in list
# ho-hum not in list
# hoodium not in list
# horrifys not in list
# hypocricy not in list
# ill-advised not in list
# ill-conceived not in list
# ill-defined not in list
# ill-designed not in list
# ill-fated not in list
# ill-favored not in list
# ill-formed not in list
# ill-mannered not in list
# ill-natured not in list
# ill-sorted not in list
# ill-tempered not in list
# ill-treated not in list
# ill-treatment not in list
# ill-usage not in list
# ill-used not in list
# imposers not in list
# impossiblity not in list
# imprecate not in list
# inadverent not in list
# inadverently not in list
# incapably not in list
# incompatability not in list
# incomprehensible not in list
# inconsequentially not in list
# inconsequently not in list
# indeterminably not in list
# indiscriminately not in list
# indiscriminating not in list
# indistinguishable not in list
# ineloquently not in list
# inexplainable not in list
# inflammed not in list
# inimically not in list
# insociable not in list
# intefere not in list
# inteferes not in list
# intolerablely not in list
# irksomeness not in list
# irksomenesses not in list
# irragularity not in list
# irrecoverableness not in list
# irrecoverablenesses not in list
# irreplacible not in list
# irretating not in list
# job-killing not in list
# jutter not in list
# jutters not in list
# laid-off not in list
# lame-duck not in list
# last-ditch not in list
# layoff-happy not in list
# left-leaning not in list
# less-developed not in list
# lesser-known not in list
# life-threatening not in list
# little-known not in list
# lividly not in list
# long-time not in list
# long-winded not in list
# low-rated not in list
# lunaticism not in list
# martyrdom-seeking not in list
# melodramatically not in list
# misbecome not in list
# misbecoming not in list
# miserableness not in list
# misrepresentation not in list
# mistified not in list
# mistrustfully not in list
# misunderstanding not in list
# misunderstandings not in list
# multi-polarization not in list
# muscle-flexing not in list
# non-confidence not in list
# one-sided not in list
# onerously not in list
# over-acted not in list
# over-awe not in list
# over-balanced not in list
# over-hyped not in list
# over-priced not in list
# over-valuation not in list
# overpayed not in list
# oversimplification not in list
# overzelous not in list
# paralize not in list
# perfidity not in list
# polemize not in list
# polution not in list
# quarrellous not in list
# quarrellously not in list
# rantingly not in list
# regreted not in list
# repugn not in list
# repugnantly not in list
# retardedness not in list
# revengefully not in list
# revulsive not in list
# rip-off not in list
# rremediable not in list
# run-down not in list
# scandels not in list
# scoldingly not in list
# screw-up not in list
# screwed-up not in list
# second-class not in list
# second-tier not in list
# self-coup not in list
# self-criticism not in list
# self-defeating not in list
# self-destructive not in list
# self-humiliation not in list
# self-interest not in list
# self-interested not in list
# self-serving not in list
# selfinterested not in list
# semi-retarded not in list
# sermonize not in list
# set-up not in list
# sh*t not in list
# short-lived not in list
# shortsightedness not in list
# sloooooooooooooow not in list
# sloooow not in list
# slooow not in list
# slow-moving not in list
# sloww not in list
# slowww not in list
# slowwww not in list
# slumpping not in list
# smuttier not in list
# smuttiest not in list
# snappishly not in list
# snobish not in list
# so-cal not in list
# spoilages not in list
# spoilled not in list
# spoon-fed not in list
# spoon-feed not in list
# sub-par not in list
# sugar-coat not in list
# sugar-coated not in list
# terror-genic not in list
# tetchily not in list
# thumb-down not in list
# thumbs-down not in list
# time-consuming not in list
# tin-y not in list
# tiringly not in list
# top-heavy not in list
# two-faced not in list
# two-faces not in list
# ultra-hardline not in list
# un-viewable not in list
# unacceptablely not in list
# unbearablely not in list
# uncomfy not in list
# uncompromisingly not in list
# unconstitutional not in list
# undependability not in list
# unintelligile not in list
# unlamentable not in list
# unlamentably not in list
# unprove not in list
# unproves not in list
# unproving not in list
# unspeakablely not in list
# unuseable not in list
# unuseably not in list
# uproarous not in list
# uproarously not in list
# upseting not in list
# villianous not in list
# villianously not in list
# villify not in list
# war-like not in list
# washed-out not in list
# water-down not in list
# watered-down not in list
# worthlessly not in list
# wripped not in list
# wripping not in list
# After check: 1853 positive words, 4470 negative words
# Debiased black 2500 accuracy: 0.9162717219589257
